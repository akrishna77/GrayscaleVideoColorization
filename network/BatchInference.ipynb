# %% [markdown]
# #Imports

# %%
import glob
import os
import math

from time import time

import keras
from keras.applications.inception_resnet_v2 import InceptionResNetV2
from keras.applications.imagenet_utils import preprocess_input

import keras.backend as K

from keras import Model
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras.layers import Input
from keras.models import load_model
from keras.optimizers import Adam
from skimage import color
from multiprocessing import Pool
from keras.layers import Conv2D, Dense, GlobalAveragePooling2D, LSTM, TimeDistributed, UpSampling2D
from keras.engine import Layer
from keras.utils import plot_model

from collections import namedtuple
from datetime import datetime
from os import listdir
from os.path import join, isfile

import re
import cv2
import numpy as np
import tensorflow as tf
from numpy import linalg as LA

# %% [markdown]
# #Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # Fusion Layer

# %%
class FusionLayer(Layer):
    def __init__(self, **kwargs):
        super(FusionLayer, self).__init__(**kwargs)

    def call(self, inputs, mask=None):
        enc_out, incep_out, rnn_out = inputs
        enc_out_shape = enc_out.shape.as_list()
        batch_size, time_steps, h, w, _ = map(lambda x: -1 if x is None else x, enc_out_shape)

        def _repeat(emb):
            # keep batch_size, time_steps axes unchanged
            # while replicating features h*w times
            emb_rep = K.tile(emb, [1, 1, h * w])
            return K.reshape(emb_rep, (batch_size, time_steps, h, w, emb.shape[2]))

        incep_rep = _repeat(incep_out)
        rnn_rep = _repeat(rnn_out)
        return K.concatenate([enc_out, incep_rep, rnn_rep], axis=4)

    def compute_output_shape(self, input_shapes):
        enc_out_shape, incep_out_shape, rnn_out_shape = input_shapes

        # Must have 3 tensors as input
        assert input_shapes and len(input_shapes) == 3

        # Batch size of the three tensors must match
        assert enc_out_shape[0] == incep_out_shape[0] == rnn_out_shape[0]

        # Number of time steps of the three tensors must match
        assert enc_out_shape[1] == incep_out_shape[1] == rnn_out_shape[1]

        # batch_size, time_steps, h, w, enc_out_depth = map(lambda x: -1 if x == None else x, enc_out_shape)
        batch_size, time_steps, h, w, enc_out_depth = enc_out_shape
        final_depth = enc_out_depth + incep_out_shape[2] + rnn_out_shape[2]
        return batch_size, time_steps, h, w, final_depth

# %% [markdown]
# # Functions

# %%
def post_process_predictions(original_l_layers, predicted_AB_layers):
    '''
    Combine original L layer and predicted AB Layers
    '''
    time_steps = frames_per_video
    total_frames = original_l_layers.shape[0]
    predicted_frames = []
    for i in range(total_frames):
        l_layer = original_l_layers[i]
        a_layer = np.multiply(predicted_AB_layers[i, time_steps - 1, :, :, 0],
                              128)  # select the first frame outof three predictions
        b_layer = np.multiply(predicted_AB_layers[i, time_steps - 1, :, :, 1], 128)
        frame = np.empty((240, 320, 3))
        frame[:, :, 0] = l_layer
        frame[:, :, 1] = a_layer
        frame[:, :, 2] = b_layer
        # frame = color.lab2rgb(frame)
        predicted_frames.append(frame)
    return np.asarray(predicted_frames)


def save_output_video(frames, output_file):
    '''
    Save the output video
    '''
    fps = 20
    size = (320, 240)
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    out = cv2.VideoWriter(output_file, fourcc, fps, size)
    for frame in frames:
        final_out = color.lab2rgb(frame)
        final_out_write_video = final_out * 255  # color.lab2rgb results values in [0,1]
        final_out_write_video = final_out_write_video.astype(np.uint8)
        out.write(final_out_write_video)
    out.release()
    
def getInputRange(frames_count, time_steps, current_frame):
    '''
    Deciding the moving window
    '''
    # this function should change according to our selection of
    frame_selection = []
    last_selection = current_frame
    for i in range(current_frame, current_frame - time_steps, -1):
        if (i < 0):
            frame_selection.append(last_selection)
        else:
            frame_selection.append(i)
            last_selection = i
    frame_selection = frame_selection[::-1]
    return frame_selection

def get_nn_input(l_layer, resnet_out):
    '''
    Define the flowchroma input
    '''
    frames_count = l_layer.shape[0]
    time_steps = frames_per_video
    X = []
    Y = []

    for i in range(frames_count):
        frame_index_selection = getInputRange(frames_count, time_steps, i)
        frame_selection = []
        resnet_selection = []
        for j in frame_index_selection:
            frame_selection.append(l_layer[j])
            resnet_selection.append(resnet_out[j])
        X.append(frame_selection)
        Y.append(resnet_selection)

    X = np.asarray(X)
    Y = np.asarray(Y)
    return [X, Y]

def get_resnet_records(frames, model):
    '''
    Parameters
    ----------
    frames - original frames without color conversion or resizing

    Details
    -------
    Implementation adopted from Deep Kolorization implementation

    Returns
    -------
    predictions - restnet predictions
    '''
    resnet_input = []
    for frame in frames:
        resized_frame = resize_pad_frame(frame, (resnet_input_height, resnet_input_width))
        gray_scale_frame = cv2.cvtColor(resized_frame, cv2.COLOR_RGB2GRAY)
        gray_scale_frame_colored = cv2.cvtColor(gray_scale_frame, cv2.COLOR_GRAY2RGB)
        resnet_input.append(gray_scale_frame_colored)
    resnet_input = np.asarray(resnet_input)

    predictions = inception_resnet_v2_predict(resnet_input, model)
    return predictions

def preprocess_frames(gray2lab_frames):
    '''
    Parameters
    ---------
    gray2lab_frames - LAB frames of Grayscale video

    Returns
    -------
    processed_l_layer - L Layer processed (L/50 - 1)
    '''
    processed = np.empty(gray2lab_frames.shape)

    processed[:, :, :, 0] = np.divide(gray2lab_frames[:, :, :, 0], 50) - 1  # data loss
    processed[:, :, :, 1] = np.divide(gray2lab_frames[:, :, :, 1], 128)
    processed[:, :, :, 2] = np.divide(gray2lab_frames[:, :, :, 2], 128)

    processed_l_layer = processed[:, :, :, np.newaxis, 0]

    return processed_l_layer

def get_lab_layer(frames):
    '''
        Parameters
        -----------
        frames - color/gray video frames with 3 chanels

        Returns
        -------
        (rgb2lab, gray2lab) - RGB frames converted to LAB, GRAY frames converted to LAB
    '''
    rgb2lab_frames = []
    gray2lab_frames = []

    for frame in frames:
        resized_frame = resize_pad_frame(frame, (default_nn_input_height, default_nn_input_width), equal_padding=True)

        rgb2lab_frame = color.rgb2lab(resized_frame)
        rgb2lab_frames.append(rgb2lab_frame)

        rgb2gray_frame = color.rgb2gray(resized_frame)

        #         Display Grayscale frame
        #         cv2.imshow('grey', rgb2gray_frame)
        #         cv2.waitKey(0)
        #         cv2.destroyAllWindows()

        gray2rgb_frame = color.gray2rgb(rgb2gray_frame)
        lab_frame = color.rgb2lab(gray2rgb_frame)
        gray2lab_frames.append(lab_frame)

    return np.asarray(rgb2lab_frames), np.asarray(gray2lab_frames)


def get_video(file, index):
    '''
    Parameters
    ----------
    file - path to video file

    Returns
    -------
    frames - frames array of the video
    '''
    video = cv2.VideoCapture(file)
    frames = []
    count = 0
    while video.isOpened():
        ret, frame = video.read()
        if not ret:
            break
        count = count + 1
        # print(count)
        if(index == 0 and count%2 ==0):
            # print(count)
            frames.append(frame)
        if(index == 1 and count%2 != 0):
            # print(count)
            frames.append(frame)

    frames = np.asarray(frames)
    return frames

def process_test_file(file):
    # Pre-processing
    frames = get_video(dir_test+'/'+file)
    (rgb2lab_frames, gray2lab_frames) = get_lab_layer(frames)
    processed_l_layer = preprocess_frames(gray2lab_frames)
    print('running resnet model')
    predictions = get_resnet_records(frames)
    print('Combining L layer and resnet out')
    X = get_nn_input(processed_l_layer, predictions)

    # Predicting
    ckpts = glob.glob("/content/drive/My Drive/checkpoints_new/*.hdf5")
    latest_ckpt = max(ckpts, key=os.path.getctime)
    print("loading from checkpoint:", latest_ckpt)
    model = load_model(latest_ckpt, custom_objects={'FusionLayer': FusionLayer})
    predictions = []
    for i in range(X[0].shape[0]):
        predictions.append(model.predict([X[0][i:i + 1], X[1][i:i + 1]])[0])  # shape is (1, 3, 240, 320, 2)
    predictions = np.asarray(predictions)
    print("Flowchroma model predictions calculated")

    # Post processing
    frame_predictions = post_process_predictions(gray2lab_frames[:, :, :, 0], predictions)

    save_output_video(frame_predictions, dir_test_results+ '/' + file.split('.')[0] + '.avi')

# %% [markdown]
# ### Resize Pad Frame

# %%
def resize_pad_frame(img, size, pad_color=255, equal_padding=True):
    """
    Resize the frame,
    If image is a horizontal one first match the horizontal axis then resize vertical axis and fill the remaining
    with padding color, similar process for vertical images
    :param equal_padding:
    :param img: frame to be resized
    :param size: final frame size
    :param pad_color: color of tha padding
    :return: re-sized frame
    """
    h, w = float(img.shape[0]), float(img.shape[1])
    expected_height, expected_width = size

    # interpolation method
    if h > expected_height or w > expected_width:  # shrinking image
        interp = cv2.INTER_AREA
    else:  # stretching image
        interp = cv2.INTER_CUBIC

    # aspect ratio of image
    aspect = w / h

    # compute scaling and pad sizing
    if aspect >= 1:  # horizontal image
        new_w = expected_width
        new_h = np.round(new_w / aspect).astype(int)
        if expected_height >= new_h:
            if equal_padding:
                pad_vert = (expected_height - new_h) / 2.0
                pad_top, pad_bot = np.floor(pad_vert).astype(int), np.ceil(pad_vert).astype(int)
                pad_left, pad_right = 0, 0
            else:
                pad_vert = (expected_height - new_h)
                pad_top, pad_bot = 0, pad_vert
                pad_left, pad_right = 0, 0
        else:
            new_h = expected_height
            new_w = np.round(new_h * aspect).astype(int)
            if equal_padding:
                pad_horz = (expected_width - new_w) / 2
                pad_left, pad_right = np.floor(pad_horz).astype(int), np.ceil(pad_horz).astype(int)
                pad_top, pad_bot = 0, 0
            else:
                pad_horz = (expected_width - new_w)
                pad_left, pad_right = 0, pad_horz
                pad_top, pad_bot = 0, 0

    elif aspect < 1:  # vertical image
        new_h = expected_height
        new_w = np.round(new_h * aspect).astype(int)
        if expected_width >= new_w:
            if equal_padding:
                pad_horz = (expected_width - new_w) / 2
                pad_left, pad_right = np.floor(pad_horz).astype(int), np.ceil(pad_horz).astype(int)
                pad_top, pad_bot = 0, 0
            else:
                pad_horz = (expected_width - new_w)
                pad_left, pad_right = 0, pad_horz
                pad_top, pad_bot = 0, 0
        else:
            new_w = expected_width
            new_h = np.round(new_w / aspect).astype(int)
            if equal_padding:
                pad_vert = (expected_height - new_h) / 2.0
                pad_top, pad_bot = np.floor(pad_vert).astype(int), np.ceil(pad_vert).astype(int)
                pad_left, pad_right = 0, 0
            else:
                pad_vert = (expected_height - new_h)
                pad_top, pad_bot = 0, pad_vert
                pad_left, pad_right = 0, 0

    # set pad color
    if len(img.shape) is 3 and not isinstance(pad_color,
                                              (list, tuple, np.ndarray)):  # color image but only one color provided
        pad_color = [pad_color] * 3

    # scale and pad
    scaled_img = cv2.resize(img, (new_w, new_h), interpolation=interp)
    scaled_img = cv2.copyMakeBorder(scaled_img, pad_top, pad_bot, pad_left, pad_right,
                                    borderType=cv2.BORDER_CONSTANT, value=pad_color)

    return scaled_img

# %% [markdown]
# #Calling Functions

# %%
def inference():
  files = listdir(dir_test)
  for file in files:
      process_test_file(file)

# %% [markdown]
# # Old Configurations

# %%
dir_root = '/content/drive/My Drive'
dir_originals = join(dir_root, 'original')
dir_sampled = join(dir_root, 'sampled')
dir_resnet_images = join(dir_root, 'resized_resnet_images')
dir_resnet_csv = join(dir_root, 'resnet_csv_records')
dir_lab_records = join(dir_root, 'lab_records')
dir_tfrecord = join(dir_root, 'tfrecords')
dir_test = join(dir_root, 'test')
dir_test_results = join(dir_root, 'test_results')
dir_frame_lab_records = join(dir_root, 'frame_lab_records')
dir_frame_resnet_records = join(dir_root, 'frame_resnet_records')
checkpoint_url = join(dir_root,"updated_resnet_v2.h5")

frames_per_video = 3
default_nn_input_height = 240
default_nn_input_width = 320
resnet_input_height = 299
resnet_input_width = 299
resnet_video_chunk_size = 100
resnet_batch_size = 100

training_set_size = 2000
test_set_size = 239
validation_set_size = 200

resnet_output = 1000


def progressive_filename_generator(pattern='file_{}.ext'):
    for i in itertools.count():
        yield pattern.format(i)

# %% [markdown]
# # New Configurations

# %%
# dir_root = '/content/drive/My Drive'
# dir_originals = join(dir_root, 'original')
# dir_sampled = join(dir_root, 'sampled_new')
# dir_resnet_images = join(dir_root, 'resized_resnet_images_new')
# dir_resnet_csv = join(dir_root, 'resnet_csv_records_new')
# dir_lab_records = join(dir_root, 'lab_records_new')
# dir_tfrecord = join(dir_root, 'tfrecords_new')
# dir_test = join(dir_root, 'test')
# dir_test_results = join(dir_root, 'test_results_new')
# dir_frame_lab_records = join(dir_root, 'frame_lab_records_new')
# dir_frame_resnet_records = join(dir_root, 'frame_resnet_records_new')
# checkpoint_url = join(dir_root,"updated_resnet_v2.h5")

# frames_per_video = 3
# default_nn_input_height = 240
# default_nn_input_width = 320
# resnet_input_height = 299
# resnet_input_width = 299
# resnet_video_chunk_size = 100
# resnet_batch_size = 100

# training_set_size = 2000
# test_set_size = 239
# validation_set_size = 200

# resnet_output = 1000


# def progressive_filename_generator(pattern='file_{}.ext'):
#     for i in itertools.count():
#         yield pattern.format(i)

# %% [markdown]
# # Inception Model

# %%
K.clear_session()
x_res_net = InceptionResNetV2(include_top=True, weights='imagenet')
# load_model(checkpoint_url)
y_res_net = x_res_net.output

def init_resnet():
  
  model = Model(inputs=x_res_net.input, outputs=y_res_net)
  return model
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:107: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:111: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4271: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.7/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels.h5
# 225214464/225209952 [==============================] - 6s 0us/step

# %%
def inception_resnet_v2_predict(images, model):
    images = images.astype(np.float32)
    predictions = model.predict(preprocess_input(images))
    return predictions

# %% [markdown]
# #INference Init

# %%
# !ls /content/drive/My\ Drive/test

# %%
# inference()

# %% [markdown]
# # Inference Visualization

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

sns.set(rc={'figure.figsize':(20,8)})

# %% [markdown]
# #Comparison (Old Vs New)

# %% [markdown]
# ##NORM

# %%
def get_norm(arr,index):
    return LA.norm(arr[0,:,:,index])
    # return np.sum(np.absolute(arr[0,:,:,index]))

# %%
frames0 = get_video('/content/drive/My Drive/test_bank/Cheetah_color.mp4',0)
frames1 = get_video('/content/drive/My Drive/test_bank/Cheetah_color.mp4',1)
# n = 3  # for 2 random indices
# index = np.random.choice(frames.shape[0], n, replace=False)  
# frames = frames[index]
len1 = frames0.shape[0]
len2 = frames1.shape[0]
len_min = min(len1, len2)
frames0 = frames0[0:len_min,:,:,:]
frames1 = frames1[0:len_min,:,:,:]
print(frames0.shape)
print(frames1.shape)
# Out:
# (286, 720, 1280, 3)
# (286, 720, 1280, 3)

# %%
# print(get_norm(frames0-frames1,0) )

# %%
# get L layer
# (rgb2lab_frames, gray2lab_frames) = get_lab_layer(frames0)
# processed_l_layer = preprocess_frames(gray2lab_frames)
# print(processed_l_layer.shape)
# print("Completed calculating L layer")

# %% [markdown]
# ## Result after epoch 003 [Old Model]

# %%
# get resnet embeddings
model = init_resnet()
predictions = get_resnet_records(frames0)
print("Completed calculating resnet records ")
# Out:
# Completed calculating resnet records

# %%
# run flowchroma model
latest_ckpt = "/content/drive/My Drive/checkpoints/flowchroma-epoch-00003-lr-0.0001-train_loss-0.0057.hdf5"
print("loading from checkpoint:", latest_ckpt)
model = load_model(latest_ckpt, custom_objects={'FusionLayer': FusionLayer})
X = get_nn_input(processed_l_layer, predictions)
predictions = model.predict(X)

print("Flowchroma model predictions calculated")
# Out:
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00003-lr-0.0001-train_loss-0.0057.hdf5
# Flowchroma model predictions calculated

# %%
frame_predictions = post_process_predictions(gray2lab_frames[:,:,:,0], predictions)
print(frame_predictions.shape)
print(rgb2lab_frames.shape)
# Out:
# (229, 240, 320, 3)
# (229, 240, 320, 3)

# %% [markdown]
# ####L Layer

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)

sns.heatmap(frame_predictions[0,80:90,80:90,0],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames[0,80:90,80:90,0],annot=True, ax=ax2 )

# %%
print(get_norm(frame_predictions - rgb2lab_frames,0))
# Out:
# 24.93077343059868

# %% [markdown]
# #### A Layer

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)
sns.heatmap(frame_predictions[0,80:90,80:90,1],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames[0,80:90,80:90,1],annot=True, ax=ax2 )

# %%
print(get_norm(frame_predictions-rgb2lab_frames,1))
# Out:
# 820.631712799877

# %% [markdown]
# ####B Layer

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)
sns.heatmap(frame_predictions[0,80:90,80:90,2],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames[0,80:90,80:90,2],annot=True, ax=ax2 )

# %%
print(get_norm(frame_predictions-rgb2lab_frames,2))
# Out:
# 1462.7423883391505

# %% [markdown]
# ## Result after epoch 261 [Old Model]

# %%
# frames = get_video('/content/drive/My Drive/test/squirrel.mp4')

# %%
# # get L layer
# (rgb2lab_frames, gray2lab_frames) = get_lab_layer(frames)
# processed_l_layer = preprocess_frames(gray2lab_frames)
# print(processed_l_layer.shape)
# print("Completed calculating L layer")

# %%
# get resnet embeddings
model = init_resnet()
predictions = get_resnet_records(frames)
print("Completed calculating resnet records ")
# Out:
# Completed calculating resnet records

# %%
# run flowchroma model
latest_ckpt = "/content/drive/My Drive/checkpoints/flowchroma-epoch-00261-lr-0.0001-train_loss-0.0003.hdf5"
print("loading from checkpoint:", latest_ckpt)
model = load_model(latest_ckpt, custom_objects={'FusionLayer': FusionLayer})
X = get_nn_input(processed_l_layer, predictions)
predictions = model.predict(X)

print("Flowchroma model predictions calculated")
# Out:
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00498-lr-0.0001-train_loss-0.0002.hdf5
# Flowchroma model predictions calculated

# %%
frame_predictions = post_process_predictions(gray2lab_frames[:,:,:,0], predictions)
print(frame_predictions.shape)
print(rgb2lab_frames.shape)
# Out:
# (49, 240, 320, 3)
# (49, 240, 320, 3)

# %% [markdown]
# ####L Layer

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)

sns.heatmap(frame_predictions[0,80:90,80:90,0],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames[0,80:90,80:90,0],annot=True, ax=ax2 )

# %%
print(get_norm(frame_predictions-rgb2lab_frames,0))
# Out:
# 86.44016695880657

# %% [markdown]
# #### A Layer

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)
sns.heatmap(frame_predictions[0,80:90,80:90,1],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames[0,80:90,80:90,1],annot=True, ax=ax2 )

# %%
print(get_norm(frame_predictions-rgb2lab_frames,1))
# Out:
# 818.8079074351564

# %% [markdown]
# ####B Layer

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)
sns.heatmap(frame_predictions[0,80:90,80:90,2],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames[0,80:90,80:90,2],annot=True, ax=ax2 )

# %%
print(get_norm(frame_predictions-rgb2lab_frames,2))
# Out:
# 1100.0516693343784

# %% [markdown]
# ## Result after epoch 498 [Old Model]

# %%
# frames = get_video('/content/drive/My Drive/test/squirrel.mp4')

# %%
# # get L layer
# (rgb2lab_frames, gray2lab_frames) = get_lab_layer(frames)
# processed_l_layer = preprocess_frames(gray2lab_frames)
# print(processed_l_layer.shape)
# print("Completed calculating L layer")

# %%
# get resnet embeddings
model = init_resnet()
predictions = get_resnet_records(frames)
print("Completed calculating resnet records ")
# Out:
# Completed calculating resnet records

# %%
# run flowchroma model
latest_ckpt = "/content/drive/My Drive/checkpoints/flowchroma-epoch-00498-lr-0.0001-train_loss-0.0002.hdf5"
print("loading from checkpoint:", latest_ckpt)
model = load_model(latest_ckpt, custom_objects={'FusionLayer': FusionLayer})
X = get_nn_input(processed_l_layer, predictions)
predictions = model.predict(X)

print("Flowchroma model predictions calculated")
# Out:
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00498-lr-0.0001-train_loss-0.0002.hdf5
# Flowchroma model predictions calculated

# %%
frame_predictions = post_process_predictions(gray2lab_frames[:,:,:,0], predictions)
print(frame_predictions.shape)
print(rgb2lab_frames.shape)
# Out:
# (49, 240, 320, 3)
# (49, 240, 320, 3)

# %% [markdown]
# ####L Layer

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)

sns.heatmap(frame_predictions[0,80:90,80:90,0],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames[0,80:90,80:90,0],annot=True, ax=ax2 )

# %%
print(get_norm(frame_predictions-rgb2lab_frames,0))
# Out:
# 86.44016695880657

# %% [markdown]
# #### A Layer

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)
sns.heatmap(frame_predictions[0,80:90,80:90,1],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames[0,80:90,80:90,1],annot=True, ax=ax2 )

# %%
print(get_norm(frame_predictions-rgb2lab_frames,1))
# Out:
# 818.8079074351564

# %% [markdown]
# ####B Layer

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)
sns.heatmap(frame_predictions[0,80:90,80:90,2],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames[0,80:90,80:90,2],annot=True, ax=ax2 )

# %%
print(get_norm(frame_predictions-rgb2lab_frames,2))
# Out:
# 1100.0516693343784

# %% [markdown]
# ## Result after epoch 261 [New Model]

# %%
model = init_resnet()

# %%
# frames2 = get_video('/content/drive/My Drive/test/squirrel.mp4')
# # get L layer
# (rgb2lab_frames, gray2lab_frames) = get_lab_layer(frames2)
# processed_l_layer = preprocess_frames(gray2lab_frames)
# print(processed_l_layer.shape)
# print("Completed calculating L layer")
# # # get resnet embeddings
predictions = get_resnet_records(frames)
print("Completed calculating resnet records ")
# Out:
# Completed calculating resnet records

# %%
# run flowchroma model
latest_ckpt = "/content/drive/My Drive/checkpoints_new/flowchroma-epoch-00261-lr-0.0001-train_loss-0.0003.hdf5"
print("loading from checkpoint:", latest_ckpt)
model = load_model(latest_ckpt, custom_objects={'FusionLayer': FusionLayer})
X = get_nn_input(processed_l_layer, predictions)
predictions = model.predict(X)

print("Flowchroma model predictions calculated")
# Out:
# loading from checkpoint: /content/drive/My Drive/checkpoints_new/flowchroma-epoch-00261-lr-0.0001-train_loss-0.0003.hdf5
# Flowchroma model predictions calculated

# %%
frame_predictions = post_process_predictions(gray2lab_frames[:,:,:,0], predictions)
print(frame_predictions.shape)
print(rgb2lab_frames.shape)
# Out:
# (3, 240, 320, 3)
# (3, 240, 320, 3)

# %% [markdown]
# ####L Layer

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)

sns.heatmap(frame_predictions[0,180:190,180:190,0],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames[0,180:190,180:190,0],annot=True, ax=ax2 )

# %%
print(get_norm(frame_predictions-rgb2lab_frames,0))
# Out:
# 7585.7699882661345

# %% [markdown]
# ####A Layer

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)
sns.heatmap(frame_predictions[0,140:150,240:250,1],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames[0,140:150,240:250,1],annot=True, ax=ax2 )

# %%
print(get_norm(frame_predictions-rgb2lab_frames,1))
# Out:
# 116179.47942832291

# %% [markdown]
# #### BLayer

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)
sns.heatmap(frame_predictions[0,80:90,80:90,2],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames[0,180:190,180:190,2],annot=True, ax=ax2 )

# %%
print(get_norm(frame_predictions-rgb2lab_frames,2))
# Out:
# 131693.60835521293

# %% [markdown]
# ##Comapre Adjacent Frames Heat Map(Model 261)

# %%
# get L layer
(rgb2lab_frames0, gray2lab_frames0) = get_lab_layer(frames0)
processed_l_layer0 = preprocess_frames(gray2lab_frames0)
print(processed_l_layer0.shape)
print("Completed calculating L layer")


(rgb2lab_frames1, gray2lab_frames1) = get_lab_layer(frames1)
processed_l_layer1 = preprocess_frames(gray2lab_frames1)
print(processed_l_layer1.shape)
print("Completed calculating L layer")
# Out:
# (286, 240, 320, 1)
# Completed calculating L layer
# (286, 240, 320, 1)
# Completed calculating L layer

# %%
# get resnet embeddings
model0 = init_resnet()
predictions0 = get_resnet_records(frames0, model0)

model1 = init_resnet()
predictions1 = get_resnet_records(frames1, model1)

print("Completed calculating resnet records ")
# Out:
# Completed calculating resnet records

# %%
# run flowchroma model
latest_ckpt = "/content/drive/My Drive/checkpoints/flowchroma-epoch-00261-lr-0.0001-train_loss-0.0003.hdf5"
print("loading from checkpoint:", latest_ckpt)
model0 = load_model(latest_ckpt, custom_objects={'FusionLayer': FusionLayer})
X0 = get_nn_input(processed_l_layer0, predictions0)
predictions0 = model0.predict(X0)


model1 = load_model(latest_ckpt, custom_objects={'FusionLayer': FusionLayer})
X1 = get_nn_input(processed_l_layer1, predictions1)
predictions1 = model1.predict(X1)

print("Flowchroma model predictions calculated")
# Out:
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00261-lr-0.0001-train_loss-0.0003.hdf5
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Flowchroma model predictions calculated

# %%
frame_predictions0 = post_process_predictions(gray2lab_frames0[:,:,:,0], predictions0)
print(frame_predictions0.shape)
print(rgb2lab_frames0.shape)

frame_predictions1 = post_process_predictions(gray2lab_frames1[:,:,:,0], predictions1)
print(frame_predictions1.shape)
print(rgb2lab_frames1.shape)
# Out:
# (286, 240, 320, 3)
# (286, 240, 320, 3)
# (286, 240, 320, 3)
# (286, 240, 320, 3)

# %% [markdown]
# ####L Layer

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)

sns.heatmap(frame_predictions0[0,80:90,80:90,0],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames0[0,80:90,80:90,0],annot=True, ax=ax2 )

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)

sns.heatmap(frame_predictions1[0,80:90,80:90,0],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames1[0,80:90,80:90,0],annot=True, ax=ax2 )

# %%
print(get_norm(frame_predictions0 - frame_predictions1,0))
print(get_norm(frame_predictions0 - frame_predictions1,1))
print(get_norm(frame_predictions0 - frame_predictions1,2))
# Out:
# 474.814491747489
# 159.2998055507514
# 153.9587013370349

# %%
print(get_norm(rgb2lab_frames0 - rgb2lab_frames1,0))
print(get_norm(rgb2lab_frames0 - rgb2lab_frames1,1))
print(get_norm(rgb2lab_frames0 - rgb2lab_frames1,2))
# Out:
# 466.3484222008725
# 250.124490679725
# 286.98319130987824

# %% [markdown]
# #### A Layer

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)
sns.heatmap(frame_predictions0[0,80:90,80:90,1],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames0[0,80:90,80:90,1],annot=True, ax=ax2 )

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)
sns.heatmap(frame_predictions1[0,80:90,80:90,1],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames1[0,80:90,80:90,1],annot=True, ax=ax2 )

# %%
print(get_norm(frame_predictions0-frame_predictions1,1))
# Out:
# 0.0

# %% [markdown]
# ####B Layer

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)
sns.heatmap(frame_predictions[0,80:90,80:90,2],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames[0,80:90,80:90,2],annot=True, ax=ax2 )

# %%
print(get_norm(frame_predictions-rgb2lab_frames,2))
# Out:
# 1125.113509212711

# %% [markdown]
# ##Comapre Adjacent Frames Heat Map(Model 498)

# %%
# get L layer
(rgb2lab_frames0, gray2lab_frames0) = get_lab_layer(frames0)
processed_l_layer0 = preprocess_frames(gray2lab_frames0)
print(processed_l_layer0.shape)
print("Completed calculating L layer")


(rgb2lab_frames1, gray2lab_frames1) = get_lab_layer(frames1)
processed_l_layer1 = preprocess_frames(gray2lab_frames1)
print(processed_l_layer1.shape)
print("Completed calculating L layer")
# Out:
# (286, 240, 320, 1)
# Completed calculating L layer
# (286, 240, 320, 1)
# Completed calculating L layer

# %%
# get resnet embeddings
model0 = init_resnet()
predictions0 = get_resnet_records(frames0, model0)

model1 = init_resnet()
predictions1 = get_resnet_records(frames1, model1)

print("Completed calculating resnet records ")
# Out:
# Completed calculating resnet records

# %%
# run flowchroma model
latest_ckpt = "/content/drive/My Drive/checkpoints/flowchroma-epoch-00498-lr-0.0001-train_loss-0.0002.hdf5"
print("loading from checkpoint:", latest_ckpt)
model0 = load_model(latest_ckpt, custom_objects={'FusionLayer': FusionLayer})
X0 = get_nn_input(processed_l_layer0, predictions0)
predictions0 = model0.predict(X0)


model1 = load_model(latest_ckpt, custom_objects={'FusionLayer': FusionLayer})
X1 = get_nn_input(processed_l_layer1, predictions1)
predictions1 = model1.predict(X1)

print("Flowchroma model predictions calculated")
# Out:
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00498-lr-0.0001-train_loss-0.0002.hdf5
# Flowchroma model predictions calculated

# %%
frame_predictions0 = post_process_predictions(gray2lab_frames0[:,:,:,0], predictions0)
print(frame_predictions0.shape)
print(rgb2lab_frames0.shape)

frame_predictions1 = post_process_predictions(gray2lab_frames1[:,:,:,0], predictions1)
print(frame_predictions1.shape)
print(rgb2lab_frames1.shape)
# Out:
# (286, 240, 320, 3)
# (286, 240, 320, 3)
# (286, 240, 320, 3)
# (286, 240, 320, 3)

# %% [markdown]
# ####L Layer

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)

sns.heatmap(frame_predictions0[0,80:90,80:90,0],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames0[0,80:90,80:90,0],annot=True, ax=ax2 )

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)

sns.heatmap(frame_predictions1[0,80:90,80:90,0],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames1[0,80:90,80:90,0],annot=True, ax=ax2 )

# %%
print(get_norm(frame_predictions0 - frame_predictions1,0))
print(get_norm(frame_predictions0 - frame_predictions1,1))
print(get_norm(frame_predictions0 - frame_predictions1,2))
# Out:
# 474.814491747489
# 197.75280750455983
# 148.07100639925227

# %% [markdown]
# #### A Layer

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)
sns.heatmap(frame_predictions0[0,80:90,80:90,1],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames0[0,80:90,80:90,1],annot=True, ax=ax2 )

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)
sns.heatmap(frame_predictions1[0,80:90,80:90,1],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames1[0,80:90,80:90,1],annot=True, ax=ax2 )

# %%
print(get_norm(frame_predictions0-frame_predictions1,1))
# Out:
# 0.0

# %% [markdown]
# ####B Layer

# %%
fig, (ax,ax2) = plt.subplots(ncols=2)
fig.subplots_adjust(wspace=0.01)
sns.heatmap(frame_predictions[0,80:90,80:90,2],annot=True, ax=ax )
sns.heatmap(rgb2lab_frames[0,80:90,80:90,2],annot=True, ax=ax2 )

# %%
print(get_norm(frame_predictions-rgb2lab_frames,2))
# Out:
# 1125.113509212711

# %% [markdown]
# #LOOP

# %%
l = os.listdir("/content/drive/My Drive/checkpoint_bank/")
a_files = []
b_files = []
for i in l:
  if i.startswith("frame_predictions_a"):
    a_files.append(i)
  else:
    b_files.append(i)

a_files.sort()
b_files.sort()

# %%
frame_predictions_a = np.array(np.load("/content/drive/My Drive/checkpoint_bank/" + a_files[-1]))
frame_predictions_b = np.array(np.load("/content/drive/My Drive/checkpoint_bank/" + b_files[-1]))

index = len(frame_predictions_b)

# %%
import os
import numpy as np


epoch = 3 

frames0 = get_video('/content/drive/My Drive/test_bank/Cheetah_color.mp4',0)
frames1 = get_video('/content/drive/My Drive/test_bank/Cheetah_color.mp4',1)
# n = 3  # for 2 random indices
# index = np.random.choice(frames.shape[0], n, replace=False)  
# frames = frames[index]
len1 = frames0.shape[0]
len2 = frames1.shape[0]
len_min = min(len1, len2)
frames0 = frames0[0:len_min,:,:,:]
frames1 = frames1[0:len_min,:,:,:]
# print(frames0.shape)
# print(frames1.shape)

(rgb2lab_frames0, gray2lab_frames0) = get_lab_layer(frames0)
processed_l_layer0 = preprocess_frames(gray2lab_frames0)
# print(processed_l_layer0.shape)
# print("Completed calculating L layer")


(rgb2lab_frames1, gray2lab_frames1) = get_lab_layer(frames1)
processed_l_layer1 = preprocess_frames(gray2lab_frames1)
# print(processed_l_layer1.shape)
# print("Completed calculating L layer")

models = os.listdir("/content/drive/My Drive/checkpoints/")
models.sort()
print(len(models))

frame_predictions_a = frame_predictions_a.tolist()
frame_predictions_b = frame_predictions_b.tolist()
itr = index+1
# Out:
# 165

# %%
for i in range(index+1, len(models)):
  print(itr)
  # get resnet embeddings
  model0 = init_resnet()
  predictions0 = get_resnet_records(frames0, model0)

  model1 = init_resnet()
  predictions1 = get_resnet_records(frames1, model1)

  print("Completed calculating resnet records ")

  # run flowchroma model
  latest_ckpt = "/content/drive/My Drive/checkpoints/" + models[i]
  print("loading from checkpoint:", latest_ckpt)
  model0 = load_model(latest_ckpt, custom_objects={'FusionLayer': FusionLayer})
  X0 = get_nn_input(processed_l_layer0, predictions0)
  predictions0 = model0.predict(X0)


  model1 = load_model(latest_ckpt, custom_objects={'FusionLayer': FusionLayer})
  X1 = get_nn_input(processed_l_layer1, predictions1)
  predictions1 = model1.predict(X1)

  print("Flowchroma model predictions calculated")

  frame_predictions0 = post_process_predictions(gray2lab_frames0[:,:,:,0], predictions0)
  # print(frame_predictions0.shape)
  # print(rgb2lab_frames0.shape)

  frame_predictions1 = post_process_predictions(gray2lab_frames1[:,:,:,0], predictions1)
  # print(frame_predictions1.shape)
  # print(rgb2lab_frames1.shape)

  # print(get_norm(frame_predictions0 - frame_predictions1,0))
  frame_predictions_a.append(get_norm(frame_predictions0 - frame_predictions1,1))
  frame_predictions_b.append(get_norm(frame_predictions0 - frame_predictions1,2))
  itr+=1
  if(itr%10 == 0):
    
    print("Last Mode Saved: " + latest_ckpt)
    np.save("/content/drive/My Drive/checkpoint_bank/frame_predictions_a_{}.npy".format(itr), frame_predictions_a)
    np.save("/content/drive/My Drive/checkpoint_bank/frame_predictions_b_{}.npy".format(itr), frame_predictions_b)

  # print(get_norm(frame_predictions0 - frame_predictions1,1))
  # print(get_norm(frame_predictions0 - frame_predictions1,2))

  # print(get_norm(rgb2lab_frames0 - rgb2lab_frames1,0))
  # print(get_norm(rgb2lab_frames0 - rgb2lab_frames1,1))
  # print(get_norm(rgb2lab_frames0 - rgb2lab_frames1,2))
# Out:
# 51
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00159-lr-0.0001-train_loss-0.0005.hdf5
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2239: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Flowchroma model predictions calculated
# 52
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00162-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# 53
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00165-lr-0.0001-train_loss-0.0005.hdf5
# Flowchroma model predictions calculated
# 54
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00168-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# 55
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00171-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# 56
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00174-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# 57
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00177-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# 58
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00180-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# 59
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00183-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# Last Mode Saved: /content/drive/My Drive/checkpoints/flowchroma-epoch-00183-lr-0.0001-train_loss-0.0004.hdf5
# 60
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00186-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# 61
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00189-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# 62
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00192-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# 63
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00195-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# 64
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00198-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# 65
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00201-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# 66
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00204-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# 67
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00207-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# 68
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00210-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# 69
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00213-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# Last Mode Saved: /content/drive/My Drive/checkpoints/flowchroma-epoch-00213-lr-0.0001-train_loss-0.0004.hdf5
# 70
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00216-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# 71
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00219-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# 72
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00222-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# 73
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00225-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# 74
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00228-lr-0.0001-train_loss-0.0004.hdf5
# Flowchroma model predictions calculated
# 75
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00231-lr-0.0001-train_loss-0.0003.hdf5
# Flowchroma model predictions calculated
# 76
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00234-lr-0.0001-train_loss-0.0003.hdf5
# Flowchroma model predictions calculated
# 77
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00237-lr-0.0001-train_loss-0.0003.hdf5
# Flowchroma model predictions calculated
# 78
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00240-lr-0.0001-train_loss-0.0003.hdf5
# Flowchroma model predictions calculated
# 79
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00243-lr-0.0001-train_loss-0.0003.hdf5
# Flowchroma model predictions calculated
# Last Mode Saved: /content/drive/My Drive/checkpoints/flowchroma-epoch-00243-lr-0.0001-train_loss-0.0003.hdf5
# 80
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00246-lr-0.0001-train_loss-0.0003.hdf5
# Flowchroma model predictions calculated
# 81
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00249-lr-0.0001-train_loss-0.0003.hdf5
# Flowchroma model predictions calculated
# 82
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00252-lr-0.0001-train_loss-0.0003.hdf5
# Flowchroma model predictions calculated
# 83
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00255-lr-0.0001-train_loss-0.0003.hdf5
# Flowchroma model predictions calculated
# 84
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00258-lr-0.0001-train_loss-0.0003.hdf5
# Flowchroma model predictions calculated
# 85
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00261-lr-0.0001-train_loss-0.0003.hdf5
# Flowchroma model predictions calculated
# 86
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00264-lr-0.0001-train_loss-0.0003.hdf5
# Flowchroma model predictions calculated
# 87
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00267-lr-0.0001-train_loss-0.0003.hdf5
# Flowchroma model predictions calculated
# 88
# Completed calculating resnet records
# loading from checkpoint: /content/drive/My Drive/checkpoints/flowchroma-epoch-00270-lr-0.0001-train_loss-0.0003.hdf5
# Flowchroma model predictions calculated
# 89

# %%
np.save("/content/drive/My Drive/frame_predictions_a.npy", frame_predictions_a)
np.save("/content/drive/My Drive/frame_predictions_b.npy", frame_predictions_b)

# %%
# !ls /content/drive/My Drive
